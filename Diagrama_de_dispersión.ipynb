# %% [markdown]
# <a href="https://colab.research.google.com/github/Christian-Munoz-98/formulas_estadisticas/blob/main/Diagrama_de_dispersi%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x= [2.4, 3.4, 4.6, 3.7, 2.2, 3.3, 4.0, 2.1]
y= [1.33, 2.12, 1.80, 1.65, 2.0, 1.76, 2.11, 1.63]

x_label = 'Cosecha de maíz'
y_label = 'Cosecha de cacahuates'


plt.scatter(x,y)
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.show()

anp = np.array([[2.4, 3.4, 4.6, 3.7, 2.2, 3.3, 4.0, 2.1],
  [1.33, 2.12, 1.80, 1.65, 2.0, 1.76, 2.11, 1.63]])

corrcoef = np.corrcoef(anp)
print(corrcoef)
# Out:
# [[1.         0.34726018]
#  [0.34726018 1.        ]]

# %%
x = [55.10, 44.83, 46.32, 51.10, 49.89, 45.20, 48.18, 46.70, 54.31, 41.50, 47.50, 52.00, 52.25, 50.86, 51.66, 54.77, 57.06, 57.84, 55.22, 59.00]
y = [49.10, 31.20, 32.80, 42.60, 42.50, 32.70, 36.21, 40.40, 37.42, 30.80, 35.34, 44.80, 41.75, 39.35, 44.07, 43.40, 45.30, 39.08, 41.89, 49.75]

x_label = 'Resistencia del cubo'
y_label = 'Resistencia del cilindro'

plt.scatter(x,y)
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.show()

anp = np.array([[55.10, 44.83, 46.32, 51.10, 49.89, 45.20, 48.18, 46.70, 54.31, 41.50, 47.50, 52.00, 52.25, 50.86, 51.66, 54.77, 57.06, 57.84, 55.22, 59.00],
  [49.10, 31.20, 32.80, 42.60, 42.50, 32.70, 36.21, 40.40, 37.42, 30.80, 35.34, 44.80, 41.75, 39.35, 44.07, 43.40, 45.30, 39.08, 41.89, 49.75]])

corrcoef = np.corrcoef(anp)
print(corrcoef)
# Out:
# [[1.         0.79886662]
#  [0.79886662 1.        ]]
